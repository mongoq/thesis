# %% [markdown]
# <a href="https://colab.research.google.com/github/mongoq/thesis/blob/main/Streaming_HAM10000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download HAM10000 Dataset in Python
#
# ---
# https://docs.activeloop.ai/datasets/ham10000-dataset

# %%
# !pip install hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 424 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 132 kB 61.6 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 45.7 MB/s
# ...
#      |████████████████████████████████| 76 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 79 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 9.1 MB 45.0 MB/s
# ...
#      |████████████████████████████████| 140 kB 57.8 MB/s
# ...
#      |████████████████████████████████| 115 kB 71.4 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 127 kB 80.2 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
import hub
ds = hub.load("hub://activeloop/ham10000")
ds.visualize()
# Out:
# hub://activeloop/ham10000 loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/ham10000
#         <iframe
#             width="90%"
#             height="800"
#             src="https://app.activeloop.ai/visualizer/hub?url=hub://activeloop/ham10000&token=eyJhbGciOiJIUzUxMiIsImlhdCI6MTY2MzYyMTE3NCwiZXhwIjoxNjY3MjIxMTc0fQ.eyJpZCI6InB1YmxpYyJ9._y8qJrhf80b4qlIAD6r2ixOxvhlq2KTpamhpMj9omGtzoyjrGqB8JDsGKbuLHl9R4pvQkBArZx2cZA2-hz1Ehw"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
#  * Serving Flask app "dataset_visualizer" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off

# %% [markdown]
# Show single image

# %%
# https://stackoverflow.com/questions/54959387/rgb-image-display-in-matplotlib-plt-imshow-returns-a-blue-image

import cv2
from google.colab.patches import cv2_imshow

image = ds.images[1].numpy()
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

cv2_imshow(image_rgb)
#cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=600x450 at 0x7F33972771D0>
