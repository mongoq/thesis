# %% [markdown]
# <a href="https://colab.research.google.com/github/mongoq/thesis/blob/main/Mini_Motorway.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import torch
from PIL import Image
from google.colab.patches import cv2_imshow

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Image
! wget -q https://miro.medium.com/max/689/1*RYOxzW7nU4sxmNplxjgxGA.png # motorway image
im1 = cv2.imread('1*RYOxzW7nU4sxmNplxjgxGA.png') 
cv2_imshow(im1)

# Inference
results = model(im1)

# Results
results.print()  
#results.save()
results.show()

#results.xyxy[0]  # im1 predictions (tensor)
#results.pandas().xyxy[0]  # im1 predictions (pandas)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-9-17 Python-3.7.14 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=689x387 at 0x7F71DD1791D0>
# image 1/1: 387x689 13 cars, 2 buss, 2 trucks
# Speed: 6.8ms pre-process, 273.9ms inference, 1.4ms NMS per image at shape (1, 3, 384, 640)
